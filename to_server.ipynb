# %%
import pandas as pd

# %%
data = pd.read_csv('./ml/predicted_company_scores.csv', )

# %%
data = data[['cik_date', 'predicted_aggregate']]

# %%
import json
import firebase_admin
from firebase_admin import credentials, firestore
import pandas as pd
epsilon = 1e-20

cred = credentials.Certificate('sass-db-firebase-adminsdk-4gh5l-4b1dd3dc87.json')
firebase_admin.initialize_app(cred)
db = firestore.client()

# %%
import numpy as np

# %%
data.to_numpy()
x = []
final_dict = dict()
for cik_date, agg in data.to_numpy():
  cik, date = cik_date.split('_')
  if str(cik) not in final_dict.keys():
    final_dict[str(cik)] = dict()
  final_dict[str(cik)][str(date)] = agg
print(final_dict)
  # x = db.collection("company").document(str(cik)).collection("_10k").document(date).get()
  # print(x.to_dict()['score'])
  # db.collection("company").document(str(cik)).collection("_10k").document(date).set({'score': agg},  merge=True)
# Out:
# {'1459417': {'2019': 0.15388614, '2020': 0.4187963, '2021': 0.0774132}, '1023731': {'2019': 0.23080128, '2020': 0.16185665, '2021': 0.21152154}, '1580808': {'2020': 0.25432217, '2021': 0.5944821}, '935036': {'2019': 0.3278039, '2020': 0.30778182, '2021': 0.5270092}, '796343': {'2019': 0.46153876, '2020': 0.6165794, '2021': 0.4616081}, '78749': {'2019': 0.25612253, '2020': 0.442744, '2021': 0.23048517}, '1459200': {'2019': 0.3850023, '2020': 0.61532944, '2021': 0.38419965}, '1701732': {'2018': 0.26688623, '2019': 0.19341433, '2020': 0.44389343, '2021': 0.30720788}, '1689923': {'2019': 0.38435167, '2020': 0.3842933, '2021': 0.26836383}, '713425': {'2019': 0.22992572, '2020': 0.23058456, '2021': 0.23190492}, '1540755': {'2019': 0.15456352, '2020': 0.22992972, '2021': 0.1544539}, '1013462': {'2019': 0.15464288, '2020': 0.15298542, '2021': 0.15402773}, '1433195': {'2019': 0.3850049, '2020': 0.6005856, '2021': 0.30832428}, '1441683': {'2018': 0.30771473, '2019': 0.23069483, '2020': 0.2298195, '2021': 0.46182933}, '1477720': {'2021': 0.23040786}, '929940': {'2019': 0.38331658, '2020': 0.34333742, '2021': 0.38504043}, '884144': {'2020': 0.23142114, '2021': 0.3069799}, '1362190': {'2021': 0.09112063}, '769397': {'2019': 0.23096406, '2020': 0.3848688, '2021': 0.6949636, '2022': 0.46150157}, '8670': {'2019': 0.4236222, '2020': 0.3416541, '2021': 0.37016672}, '1348036': {'2018': 0.15278676, '2019': 0.15450123, '2020': 0.1576165, '2021': 0.33453888}, '1418100': {'2019': 0.38457718, '2020': 0.30694056, '2021': 0.23122147}, '1015739': {'2020': 0.08463022, '2021': 0.07816264}, '1576169': {'2018': 0.15330017, '2019': 0.15396601, '2020': 0.14369303, '2021': 0.38479084}, '1031308': {'2020': 0.5380645, '2021': 0.45333508}, '1626450': {'2020': 0.15325287, '2021': 0.38443804}, '1786352': {'2020': 0.2305128, '2021': 0.39244762}, '1019034': {'2018': 0.08101362, '2019': 0.30844146, '2020': 0.082797945}, '1280058': {'2019': 0.15314695, '2020': 0.15449005, '2021': 0.15586308}, '1567900': {'2018': 0.15369567, '2019': 0.30769587, '2020': 0.07769647}, '1666134': {'2018': 0.2309036, '2019': 0.23057538, '2020': 0.38440216, '2021': 0.46163362}, '1073349': {'2019': 0.3072422, '2020': 0.23012915, '2021': 0.46177056}, '1624512': {'2018': 0.07774678, '2019': 0.30720073, '2020': 0.23073}, '1378590': {'2019': 0.0767549, '2020': 0.18456453, '2021': 0.15355638}, '1567771': {'2018': 0.15419096, '2019': 0.078284174, '2020': 0.13090071}, '1054721': {'2018': 0.07733691, '2019': 0.110506296, '2020': 0.15356597, '2021': 0.07698861}, '813672': {'2019': 0.615185, '2021': 0.61578906, '2022': 0.6560519}, '1609702': {'2019': 0.30726987, '2020': 0.6152406, '2021': 0.46190423}, '1768267': {'2020': 0.23109719, '2021': 0.538147}, '1725057': {'2018': 0.22830153, '2019': 0.46169007, '2020': 0.30779958}, '1451797': {'2019': 0.076589495}, '1169652': {'2020': 0.2317594, '2021': 0.61548996}, '945384': {'2018': 0.07712641, '2019': 0.07677513}, '1022505': {'2019': 0.07693812, '2020': 0.07799524, '2021': 0.07668921}, '877890': {'2019': 0.45282486, '2020': 0.46124637, '2021': 0.3086592}, '827876': {'2018': 0.076986134, '2019': 0.07664618, '2020': 0.15319633, '2021': 0.23075792}, '1393548': {'2021': 0.07714811}, '1535379': {'2019': 0.24684626, '2020': 0.4617098, '2021': 0.2693243}, '1477333': {'2019': 0.14775637, '2020': 0.15420431, '2021': 0.3079564}, '1169561': {'2019': 0.30863124, '2020': 0.3081516, '2021': 0.3076184}, '1401680': {'2019': 0.2934394, '2020': 0.26635134}, '1385867': {'2019': 0.30723816, '2020': 0.46244642, '2021': 0.5384959, '2022': 0.46166235}, '1535527': {'2020': 0.15428504, '2021': 0.23107708, '2022': 0.38461676}, '1561550': {'2019': 0.24041846, '2020': 0.38444182, '2021': 0.23069629}, '1724570': {'2020': 0.24186468, '2021': 0.47063288}, '317788': {'2019': 0.114274025, '2020': 0.15418762, '2021': 0.58945024}, '1261333': {'2019': 0.2514161, '2020': 0.21901065, '2021': 0.34331387}, '1505952': {'2019': 0.23063189, '2020': 0.15377077, '2021': 0.15456104}, '1467623': {'2020':  ...

# %%
x = np.array(x)
print(np.unique(x).shape)
# Out:
# (131,)

# %%
# cik,

x = db.collection("company").document(str(320340)).collection("_10k").document('2019-12-31').get()
print(x.to_dict()['score'])
# Out:
# 0.47859406

# %%
x = db.collection("company").get()

# %%
print(len(x))
# Out:
# 162

# %%
len(final_dict.keys())
# Out:
# 160

# %%
for cik in final_dict.keys():
    db.collection("company").document(str(cik)).set({"score" : final_dict[cik]}, merge=True)
